# %%
import pandas as pd
import numpy as np

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
# %matplotlib inline

# %%
dataframe = pd.DataFrame(np.random.randn(100,4), columns= ['a', 'b', 'c', 'd'])

# %%
dataframe
# Out:
#            a         b         c         d
# 0   0.948891  0.804323  1.545111 -0.970705
# 1  -0.603679  0.975958  2.065040  2.178920
# 2  -0.083558  0.044108 -0.962639 -0.548160
# 3  -0.360958 -0.664303  2.587720  2.355313
# 4   0.807148 -0.768789 -0.020525  0.594392
# ..       ...       ...       ...       ...
# 95 -0.135944 -0.046522 -1.079407  3.359581
# 96  0.103411 -1.549332 -0.307549 -0.966728
# 97  0.269767  0.479659  0.987115  0.690970
# 98  0.579673 -0.396884  0.199628 -0.254301
# 99 -0.333227  1.187697 -0.796204  0.797014
#
# [100 rows x 4 columns]

# %%
dataframe.plot()
# Out:
# <Axes: >

# %%
dataframe.plot(kind='scatter', x='a', y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
aggregated_df = dataframe.groupby(['a', 'b'])['c'].sum().reset_index()
pivot_df = aggregated_df.pivot(index='a', columns='b', values='c')
pivot_df.iplot(kind='surface')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 3
#       1 aggregated_df = dataframe.groupby(['a', 'b'])['c'].sum().reset_index()
#       2 pivot_df = aggregated_df.pivot(index='a', columns='b', values='c')
# ----> 3 pivot_df.iplot(kind='surface')
#
# ...
